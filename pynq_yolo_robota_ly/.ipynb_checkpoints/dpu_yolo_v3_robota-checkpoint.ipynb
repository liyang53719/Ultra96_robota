# %% [markdown]
# # DPU example: Yolo_v3
#
# This notebooks shows how to run a YOLO network based application for object detection. The application, as well as the DPU IP, is pulled from the official [Vitis AI Github Repository](https://github.com/Xilinx/Vitis-AI).
# For more information, please refer to the [Xilinx Vitis AI page](https://www.xilinx.com/products/design-tools/vitis/vitis-ai.html).
#
# In this notebook we will be using the DNNDK **Python API** to run the DPU tasks.
#
# ## 1. Prepare the overlay
# We will download the overlay onto the board. Then we will load the
# corresponding DPU model.

# %%
from pynq_dpu import DpuOverlay
overlay = DpuOverlay("dpu.bit")
overlay.load_model("dpu_tf_yolov3.elf")

# %% [markdown]
# ## 2. Constants and helper functions
#
# You can view all of the helper functions in [DNNDK yolo example](https://github.com/Xilinx/Vitis-AI/blob/v1.1/mpsoc/vitis_ai_dnndk_samples/tf_yolov3_voc_py/tf_yolov3_voc.py).
# The helper functions released along with Vitis AI cover pre-processing of
# the images, so they can be normalized and resized to be compatible with
# the DPU model. These functions are included in our `pynq_dpu` package.

# %%
import numpy as np
import random
import cv2
import colorsys
from PIL import Image
from matplotlib.patches import Rectangle
import matplotlib.pyplot as plt
# %matplotlib inline
from pynq_dpu.edge.dnndk.tf_yolov3_voc_py.tf_yolov3_voc import *

import serial
import math 
import threading
import time

# %% [markdown]
# ### Constants
#
# Yolo V2 and V3 predict offsets from a predetermined set of boxes with
# particular height-width ratios; those predetermined set of boxes are the
# anchor boxes. We will use the predefined [anchors](https://github.com/Xilinx/Vitis-AI/blob/v1.1/mpsoc/vitis_ai_dnndk_samples/tf_yolov3_voc_py/model_data/yolo_anchors.txt).

# %%
anchor_list = [10,13,16,30,33,23,30,61,62,45,59,119,116,90,156,198,373,326]
anchor_float = [float(x) for x in anchor_list]
anchors = np.array(anchor_float).reshape(-1, 2)
do_display = 1;

# %% [markdown]
# We will use the `get_class()` function in `tf_yolov3_voc` module to
# get class names from predefined [class names](https://github.com/Xilinx/Vitis-AI/blob/v1.1/mpsoc/vitis_ai_dnndk_samples/tf_yolov3_voc_py/image/voc_classes.txt).

# %%
classes_path = "img/voc_classes.txt"
class_names = get_class(classes_path)

# %% [markdown]
# Depending on the number of classes, we will define a unique color for each
# class.

# %%
num_classes = len(class_names)
hsv_tuples = [(1.0 * x / num_classes, 1., 1.) for x in range(num_classes)]
colors = list(map(lambda x: colorsys.hsv_to_rgb(*x), hsv_tuples))
colors = list(map(lambda x: 
                  (int(x[0] * 255), int(x[1] * 255), int(x[2] * 255)), 
                  colors))
random.seed(0)
random.shuffle(colors)
random.seed(None)

# %% [markdown]
# We can define some DPU-related parameters, such as DPU kernel name and
# input/output node names.

# %%
KERNEL_CONV="tf_yolov3"
CONV_INPUT_NODE="conv2d_1_convolution"
CONV_OUTPUT_NODE1="conv2d_59_convolution"
CONV_OUTPUT_NODE2="conv2d_67_convolution"
CONV_OUTPUT_NODE3="conv2d_75_convolution"

# %% [markdown]
# ### Drawing bounding boxes
# We now define a custom function that draws the bounding boxes around
# the identified objects after we have the classification results.

# %%
def draw_boxes(image, boxes, scores, classes):
    _, ax = plt.subplots(1)
    ax.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    image_h, image_w, _ = image.shape

    for i, bbox in enumerate(boxes):
        [top, left, bottom, right] = bbox
        width, height = right - left, bottom - top
        center_x, center_y = left + width*0.5, top + height*0.5
        score, class_index = scores[i], classes[i]
        label = '{}: {:.4f}'.format(class_names[class_index], score) 
        color = tuple([color/255 for color in colors[class_index]])
        ax.add_patch(Rectangle((left, top), width, height,
                               edgecolor=color, facecolor='none'))
        ax.annotate(label, (center_x, center_y), color=color, weight='bold', 
                    fontsize=12, ha='center', va='center')
    return ax

# %% [markdown]
# ### Predicting classes
# We need to define a function that evaluates the scores and makes predictions
# based on the provided class names.

# %%
def evaluate(yolo_outputs, image_shape, class_names, anchors):
    score_thresh = 0.2
    anchor_mask = [[6, 7, 8], [3, 4, 5], [0, 1, 2]]
    boxes = []
    box_scores = []
    input_shape = np.shape(yolo_outputs[0])[1 : 3]
    input_shape = np.array(input_shape)*32

    for i in range(len(yolo_outputs)):
        _boxes, _box_scores = boxes_and_scores(
            yolo_outputs[i], anchors[anchor_mask[i]], len(class_names), 
            input_shape, image_shape)
        boxes.append(_boxes)
        box_scores.append(_box_scores)
    boxes = np.concatenate(boxes, axis = 0)
    box_scores = np.concatenate(box_scores, axis = 0)

    mask = box_scores >= score_thresh
    boxes_ = []
    scores_ = []
    classes_ = []
    for c in range(len(class_names)):
        class_boxes_np = boxes[mask[:, c]]
        class_box_scores_np = box_scores[:, c]
        class_box_scores_np = class_box_scores_np[mask[:, c]]
        nms_index_np = nms_boxes(class_boxes_np, class_box_scores_np) 
        class_boxes_np = class_boxes_np[nms_index_np]
        class_box_scores_np = class_box_scores_np[nms_index_np]
        classes_np = np.ones_like(class_box_scores_np, dtype = np.int32) * c
        boxes_.append(class_boxes_np)
        scores_.append(class_box_scores_np)
        classes_.append(classes_np)
    boxes_ = np.concatenate(boxes_, axis = 0)
    scores_ = np.concatenate(scores_, axis = 0)
    classes_ = np.concatenate(classes_, axis = 0)

    return boxes_, scores_, classes_

# %% [markdown]
# ### Prepare the robot environment

# %%
foot_step_y =  [279.784161172141,279.186908630917,278.277002300741,277.115005759996,275.754049819188,274.240538017160,272.614797512661,270.911678712097,269.161106838920,267.388588516087,265.615676300516,263.860393977703,262.137625295807,260.459468691776,258.835560437576,257.273368512539,255.778459388321,254.354739796168,253.004675432211,251.729488445440,250.529335445055,249.403467658971,248.350374773650,247.367913887052,246.453424911499,245.603833671643,244.815743854573,244.085518884410,243.409354712554,242.783344437067,242.203535590490,241.665980864702,241.166782974233,240.702134295633,240.268351860143,239.861908219853,239.479458653788,239.117865129785,238.774217390597,238.445851488256,238.130366049206,237.825636514050,237.529827559732,237.241403878501,236.959139456928,236.682125469386,236.409776873649,236.141837771345,235.878385572837,235.619833984375,235.366934815005,235.120778581331,234.882793869785,234.654745398101,234.438730700184,234.237175341054,234.052826550887,233.888745149043,233.748295610053,233.635134103552,233.553194318798,233.506670861300,233.499999983990,233.537837387820,233.625032796419,233.766600976033,233.967688835097,234.233538197038,234.569443794824,234.980705986075,235.472577632684,236.050204528515,236.718558692392,237.482363770785,238.346011714935,239.313469810093,240.388177039675,241.572928663905,242.869747780455,244.279742513152,245.802947343574,247.438146958587,249.182680834279,251.032226612511,252.980560150118,255.019289931825,257.137563335859,259.321742025226,261.555043507194,263.817145658071,266.083750749154,268.326105232242,270.510471248619,272.597545513279,274.541820895751,276.290885669441,277.784655032326,278.954529112336,279.722471260182,280,280.157035805566,280.313935001052,280.470524379144,280.626649404310,280.782155999279,280.936890697097,281.090700792585,281.243434493039,281.394941068032,281.545070998166,281.693676122632,281.840609785429,281.985726980093,282.128884492803,282.269941043716,282.408757426397,282.545196645194,282.679124050441,282.810407471340,282.938917346399,283.064526851294,283.187112024028,283.306551887270,283.422728567744,283.535527412556,283.644837102345,283.750549761139,283.852561062818,283.950770334074,284.045080653759,284.135398948539,284.221636084743,284.303706956333,284.381530568888,284.455030119539,284.524133072763,284.588771231970,284.648880806803,284.704402476090,284.755281446392,284.801467506071,284.842915074851,284.879583248794,284.911435840669,284.938441415667,284.960573322422,284.977809719312,284.990133596013,284.997532790291,285.000000000000,284.997532790291,284.990133596013,284.977809719312,284.960573322422,284.938441415667,284.911435840669,284.879583248794,284.842915074851,284.801467506071,284.755281446392,284.704402476090,284.648880806803,284.588771231970,284.524133072763,284.455030119539,284.381530568888,284.303706956333,284.221636084743,284.135398948539,284.045080653759,283.950770334074,283.852561062818,283.750549761139,283.644837102345,283.535527412556,283.422728567744,283.306551887270,283.187112024028,283.064526851294,282.938917346399,282.810407471340,282.679124050441,282.545196645194,282.408757426397,282.269941043716,282.128884492803,281.985726980093,281.840609785429,281.693676122632,281.545070998166,281.394941068032,281.243434493039,281.090700792585,280.936890697097,280.782155999279,280.626649404310,280.470524379144,280.313935001052,280.157035805566,279.999981633974];
foot_step_x = [64.7962241881123,66.9281948440417,68.9047458853030,70.7336632089232,72.4214871275340,73.9734081466605,75.3932398834638,76.6834545548556,77.8452679930586,78.8787625824203,79.7830378556315,80.5563797434742,81.1964406427908,81.7004235554845,82.0652645599333,82.2878088081130,82.3649760998204,82.2939128724922,82.0721281639968,81.6976117592065,81.1689333218330,80.4853218436418,79.6467252163808,78.6538501502127,77.5081830286980,76.2119926070127,74.7683157296147,73.1809274684994,71.4542972659614,69.5935328088481,67.6043134670304,65.4928151996159,63.2656288705983,60.9296739234989,58.4921093443607,55.9602437964515,53.3414467404231,50.6430622626238,47.8723272239227,45.0362952138752,42.1417676524195,39.1952332255899,36.2028166749700,33.1702377847724,30.1027812274658,27.0052777406881,23.8820969166770,20.7371516924551,17.5739144363544,14.3954443359375,11.2044256057212,8.00321585206032,4.79390375878943,1.57837509240965,-1.64161412862989,-4.86435859807750,-8.08812024531625,-11.3110418570447,-14.5310594324856,-17.7458149855232,-20.9525715656347,-24.1481323068966,-27.3287653293420,-30.4901363081892,-33.6272504926440,-36.7344058958352,-39.8051592897264,-42.8323065223615,-45.8078785283573,-48.7231542260251,-51.5686912847656,-54.3343755033598,-57.0094892624317,-59.5827992016640,-62.0426629233360,-64.3771541374586,-66.5742052392998,-68.6217658465369,-70.5079753197783,-72.2213467459584,-73.7509592783283,-75.0866550986851,-76.2192365963852,-77.1406586438718,-77.8442100892641,-78.3246777823629,-78.5784856006467,-78.6038000458836,-78.4005930393470,-77.9706515537933,-77.3175226828730,-76.4463816630621,-75.3638092291274,-74.0774635011926,-72.5956303693243,-70.9266350598978,-69.0780962365581,-67.0560026071199,-64.8635905760431,-62.5000000000000,-61.2500000000000,-60,-58.7500000000000,-57.5000000000000,-56.2500000000000,-55,-53.7500000000000,-52.5000000000000,-51.2500000000000,-50,-48.7500000000000,-47.5000000000000,-46.2500000000000,-45,-43.7500000000000,-42.5000000000000,-41.2500000000000,-40,-38.7500000000000,-37.5000000000000,-36.2500000000000,-35,-33.7500000000000,-32.5000000000000,-31.2500000000000,-30,-28.7500000000000,-27.5000000000000,-26.2500000000000,-25,-23.7500000000000,-22.5000000000000,-21.2500000000000,-20.0000000000000,-18.7500000000000,-17.5000000000000,-16.2500000000000,-15,-13.7500000000000,-12.5000000000000,-11.2500000000000,-10.0000000000000,-8.75000000000000,-7.50000000000000,-6.25000000000000,-5.00000000000000,-3.75000000000000,-2.50000000000000,-1.25000000000000,0,1.25000000000000,2.50000000000000,3.75000000000000,5.00000000000000,6.25000000000001,7.50000000000001,8.75000000000000,10.0000000000000,11.2500000000000,12.5000000000000,13.7500000000000,15,16.2500000000000,17.5000000000000,18.7500000000000,20.0000000000000,21.2500000000000,22.5000000000000,23.7500000000000,25.0000000000000,26.2500000000000,27.5000000000000,28.7500000000000,30,31.2500000000000,32.5000000000000,33.7500000000000,35,36.2500000000000,37.5000000000000,38.7500000000000,40.0000000000000,41.2500000000000,42.5000000000000,43.7500000000000,45,46.2500000000000,47.5000000000000,48.7500000000000,50,51.2500000000000,52.5000000000000,53.7500000000000,55.0000000000000,56.2500000000000,57.5000000000000,58.7500000000000,60,61.2500000000000,62.5000000000000];

# %%
#Function to calculate roll, hip and knee angles from the x,y,z coords of the foot wrt the hip.
def xyztoang(x,y,z,yoffh,hu,hl):
    dyz=np.sqrt(y**2+z**2)
    lyz=np.sqrt(dyz**2-yoffh**2)
    gamma_yz=-np.arctan(y/z)
    gamma_h_offset=-np.arctan(-yoffh/lyz)
    gamma=gamma_yz-gamma_h_offset

    lxzp=np.sqrt(lyz**2+x**2)
    n=(lxzp**2-hl**2-hu**2)/(2*hu)
    beta=-np.arccos(n/hl)

    alfa_xzp=-np.arctan(x/lyz)
    alfa_off=np.arccos((hu+n)/lxzp)
    alfa=alfa_xzp+alfa_off
    if any( np.isnan([gamma,alfa,beta])):
        print(x,y,z,yoffh,hu,hl)
    return [alfa,beta,gamma]

# %%
def pose_control(rpy_r,rpy_p,rpy_y,pos_x, pos_y, pos_z):
    # 定义结构参数
    b = 120;
    w = 120;
    l = 250;
    # 定义目标位姿
    #pos = np.mat([0.0,  0.0,  0.3 ]).T # 目标位置向量
    #	rpy = np.array([0.0,  0.0,  0.0]) * math.pi / 180 # 欧拉角，化为弧度值
    # 将欧拉角转换为旋转矩阵
    #	R, P, Y = rpy[0], rpy[1], rpy[2]
    pos = np.mat([pos_x,  pos_y,  pos_z ]).T

    R = rpy_r;
    P = rpy_p;
    Y = rpy_y;

    rotx = np.mat([[ 1,       0,            0          ],
         [ 0,       math.cos(R), -math.sin(R)],
         [ 0,       math.sin(R),  math.cos(R)]])
    roty = np.mat([[ math.cos(P),  0,      -math.sin(P)],
         [ 0,            1,       0          ],
         [ math.sin(P),  0,       math.cos(P)]]) 
    rotz = np.mat([[ math.cos(Y), -math.sin(Y),  0     ],
         [ math.sin(Y),  math.cos(Y),  0     ],
         [ 0,            0,            1     ]])
    rot_mat = rotx * roty * rotz
    # 结构参数
    body_struc = np.mat([[ l / 2,  b / 2,  0],
               [ l / 2, -b / 2,  0],
               [-l / 2,  b / 2,  0],
               [-l / 2, -b / 2,  0]]).T
    footpoint_struc = np.mat([[ l / 2,  w / 2,  0],
                    [ l / 2, -w / 2,  0],
                    [-l / 2,  w / 2,  0],
                    [-l / 2, -w / 2,  0]]).T
    # 计算单腿末端位置向量AB
    AB = np.mat(np.zeros((3, 4)))
    leg_pose = np.mat(np.zeros((3, 4)))
    position_pos = np.mat(np.zeros((3, 4)))
    for i in range(4):
        leg_pose[:, i] = - pos - rot_mat * body_struc[:, i] + footpoint_struc[:, i]
  
    return leg_pose

# %%
def serial_walk_control(rpy_r,rpy_p,rpy_y,pos_x, pos_y, pos_z,t,foot_step_x,foot_step_y, setp_count, setp_depth):
    position_zero=[ 1500,   1500,    1500,
                    1500,   1500,    1500,
                    1500,   1500,    1500,
                    1500,   1500,    1500];
    z_gain    = 0.2 * setp_depth#250;
    x_gaim    = 0.4 * setp_depth#400;
    time_step = 1 #50;
    leg_pose = np.mat(np.zeros((3, 4)))
    j = setp_count;
    length_lut = len(foot_step_x);

    leg_pose = pose_control(rpy_r,rpy_p,rpy_y,pos_x, pos_y, pos_z);

    lf_x  = leg_pose[0,0] - x_gaim*(foot_step_x[setp_count%length_lut]);
    lf_y  = leg_pose[1,0];
    lf_z  = leg_pose[2,0] + z_gain*(foot_step_y[setp_count%length_lut]-230);
    lb_x  = leg_pose[0,1] - x_gaim*(foot_step_x[(setp_count + (length_lut>>1))%length_lut]);
    lb_y  = leg_pose[1,1];
    lb_z  = leg_pose[2,1] + z_gain*(foot_step_y[(setp_count + (length_lut>>1))%length_lut]-230);
    rf_x  = leg_pose[0,2] - x_gaim*(foot_step_x[(setp_count + (length_lut>>1))%length_lut]);
    rf_y  = leg_pose[1,2];
    rf_z  = leg_pose[2,2] + z_gain*(foot_step_y[(setp_count + (length_lut>>1))%length_lut]-230);
    rb_x  = leg_pose[0,3] - x_gaim*(foot_step_x[setp_count%length_lut]);
    rb_y  = leg_pose[1,3];
    rb_z  = leg_pose[2,3] + z_gain*(foot_step_y[setp_count%length_lut]-230);

    [lf_alfa,lf_beta,lf_gamma]=xyztoang(lf_x,lf_y,lf_z,0,105,130);
    [lb_alfa,lb_beta,lb_gamma]=xyztoang(lb_x,lb_y,lb_z,0,105,130);
    [rf_alfa,rf_beta,rf_gamma]=xyztoang(rf_x,rf_y,rf_z,0,105,130);
    [rb_alfa,rb_beta,rb_gamma]=xyztoang(rb_x,rb_y,rb_z,0,105,130);

    #position_pos = fix(position_angle/pi*180/135*1000);
    const = 1000/3.1416*180/135;
    position_angle =        [-rf_beta  * const , -rf_alfa * const , rf_gamma * const ,
                              lf_beta  * const ,  lf_alfa * const , lf_gamma * const ,
                             -rb_beta  * const , -rb_alfa * const ,-rb_gamma * const ,
                              lb_beta  * const ,  lb_alfa * const ,-lb_gamma * const ];

    position_pos = np.trunc(position_angle);
    pose_print = position_pos + position_zero;

    for i in range(12): #=1:12
        position  = np.int(position_zero[i] + position_pos[i]);
        send_text = "#"+str(i+1)+"P"+str(position)+"T"+str(t)+"!";
        result=ser.write(send_text.encode("UTF-8"))
        #print("send_text",send_text,position)
        time.sleep(0.002)
    return position_pos

# %%
def walk_frount(direction):
    setp_depth = 0;
    setp_count = 0;
    i = 0;
    while i < 800:
        i = i + 20;
        
        if i < 200:
            if setp_depth < 1:
                setp_depth = setp_depth + 0.1
            else:
                setp_depth = 1                
        elif i > 600:
            if setp_depth > 0:
                setp_depth = setp_depth - 0.1
            else:
                setp_depth = 0

        length_lut = len(foot_step_x)
        setp_count = setp_count + 20 ;
        setp_count = int(setp_count%(len(foot_step_x)*2-1))

        #print("setp_count:", setp_count%length_lut, (setp_count + length_lut>>1)%length_lut,(setp_count + (length_lut>>1))%length_lut)

        if direction == 1: #go frount
            serial_walk_control(0.0,0.0,0,10,0,-150,40,foot_step_x,foot_step_y, setp_count, setp_depth);
        elif direction == 0: #go back
            serial_walk_control(0.0,0.0,0,10,0,-150,40,foot_step_x,foot_step_y, setp_count-199, setp_depth);
        time.sleep(0.04)
    return 0

# %%
capture = cv2.VideoCapture(0)
# 打开自带的摄像头
if capture.isOpened():
    # 以下两步设置显示屏的宽高
    print('capture isOpened')
    capture.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
    capture.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)
    read_code,image = capture.read()
    if do_display == 1 :
        _, ax = plt.subplots(1)
        _ = ax.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    else:
        print('chose not to dispaly image')
    #capture.release()
else:
    print('capture open fail!!!')
# Out:
# capture isOpened

# %% [markdown]
# The following cell will normalize the input picture size.

# %%
image_size = image.shape[:2]
image_data = np.array(pre_process(image, (416, 416)), dtype=np.float32)

# %% [markdown]
# ## 3. Run application
#
# We create DPU kernel and task.

# %%
n2cube.dpuOpen()
kernel = n2cube.dpuLoadKernel(KERNEL_CONV)
task = n2cube.dpuCreateTask(kernel, 0)

# %% [markdown]
# Now we execute the DPU task to classify an input picture.

# %%
input_len = n2cube.dpuGetInputTensorSize(task, CONV_INPUT_NODE)
n2cube.dpuSetInputTensorInHWCFP32(
    task, CONV_INPUT_NODE, image_data, input_len)

n2cube.dpuRunTask(task)

conv_sbbox_size = n2cube.dpuGetOutputTensorSize(task, CONV_OUTPUT_NODE1)
conv_out1 = n2cube.dpuGetOutputTensorInHWCFP32(task, CONV_OUTPUT_NODE1, 
                                               conv_sbbox_size)
conv_out1 = np.reshape(conv_out1, (1, 13, 13, 75))

conv_mbbox_size = n2cube.dpuGetOutputTensorSize(task, CONV_OUTPUT_NODE2)
conv_out2 = n2cube.dpuGetOutputTensorInHWCFP32(task, CONV_OUTPUT_NODE2, 
                                               conv_mbbox_size)
conv_out2 = np.reshape(conv_out2, (1, 26, 26, 75))

conv_lbbox_size = n2cube.dpuGetOutputTensorSize(task, CONV_OUTPUT_NODE3)
conv_out3 = n2cube.dpuGetOutputTensorInHWCFP32(task, CONV_OUTPUT_NODE3, 
                                               conv_lbbox_size)
conv_out3 = np.reshape(conv_out3, (1, 52, 52, 75))

yolo_outputs = [conv_out1, conv_out2, conv_out3]

# %% [markdown]
# We can call the `evaluate()` function defined previously now. Depending on
# how many objects can be identified in the picture, the function returns
# a list of bounding box coordinates, a list of probability scores, and a list
# of class indexes.

# %%
boxes, scores, classes = evaluate(yolo_outputs, image_size, 
                                  class_names, anchors)

# %% [markdown]
# Once we have all the bounding boxes, classes, and scores, we can feed them to
# the `draw_boxes()` function to draw the bounding boxes over each recognized object.

# %%
if do_display == 1 :
    _ = draw_boxes(image, boxes, scores, classes)
else:
    print('chose not to dispaly image')
print('first image runing OK!')
# Out:
# first image runing OK!

# %%
### open Serial
portx = "/dev/ttyUSB1"
bps = 115200
timex = 5

ser=serial.Serial(portx,bps,timeout=timex)

print("serial isOpened!!")
# Out:
# serial isOpened!!

# %%
# run in streaming mode
i = 0;
while i < 1:
    i = i + 1;    
    read_code,image = capture.read()
    image_size = image.shape[:2]
    image_data = np.array(pre_process(image, (416, 416)), dtype=np.float32)
    
    input_len = n2cube.dpuGetInputTensorSize(task, CONV_INPUT_NODE)
    n2cube.dpuSetInputTensorInHWCFP32(
        task, CONV_INPUT_NODE, image_data, input_len)

    n2cube.dpuRunTask(task)

    conv_sbbox_size = n2cube.dpuGetOutputTensorSize(task, CONV_OUTPUT_NODE1)
    conv_out1 = n2cube.dpuGetOutputTensorInHWCFP32(task, CONV_OUTPUT_NODE1, 
                                                   conv_sbbox_size)
    conv_out1 = np.reshape(conv_out1, (1, 13, 13, 75))

    conv_mbbox_size = n2cube.dpuGetOutputTensorSize(task, CONV_OUTPUT_NODE2)
    conv_out2 = n2cube.dpuGetOutputTensorInHWCFP32(task, CONV_OUTPUT_NODE2, 
                                                   conv_mbbox_size)
    conv_out2 = np.reshape(conv_out2, (1, 26, 26, 75))

    conv_lbbox_size = n2cube.dpuGetOutputTensorSize(task, CONV_OUTPUT_NODE3)
    conv_out3 = n2cube.dpuGetOutputTensorInHWCFP32(task, CONV_OUTPUT_NODE3, 
                                                   conv_lbbox_size)
    conv_out3 = np.reshape(conv_out3, (1, 52, 52, 75))

    yolo_outputs = [conv_out1, conv_out2, conv_out3]  

    boxes, scores, classes = evaluate(yolo_outputs, image_size, 
                                  class_names, anchors)
    print(boxes, scores, classes)
    
    if do_display == 1 :
        #_, ax = plt.subplots(1)
        #_ = ax.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        _ = draw_boxes(image, boxes, scores, classes)
    else:
        print('chose not to dispaly image')
    
    if 7 in classes: # == 7 :#cat
        #walk back
        walk_frount(0)
        print('walk back')
    elif 14 in classes :# == 14: #person
        #walk frount 
        walk_frount(1)
        print('walk frount')
    else:
        print('Stand still')
# Out:
# [[  90.87052155   33.07691574  481.46908569  606.9230957 ]] [ 0.57524073] [14]
# setp_count: 20 110 120
# send_text #1P2245T40! 2245
# send_text #2P1050T40! 1050
# send_text #3P1500T40! 1500
# send_text #4P754T40! 754
# send_text #5P1965T40! 1965
# send_text #6P1500T40! 1500
# send_text #7P2246T40! 2246
# send_text #8P1035T40! 1035
# send_text #9P1500T40! 1500
# send_text #10P755T40! 755
# send_text #11P1950T40! 1950
# send_text #12P1500T40! 1500
# setp_count: 40 120 140
# send_text #1P2239T40! 2239
# send_text #2P1052T40! 1052
# send_text #3P1500T40! 1500
# send_text #4P753T40! 753
# send_text #5P1965T40! 1965
# send_text #6P1500T40! 1500
# send_text #7P2247T40! 2247
# send_text #8P1035T40! 1035
# send_text #9P1500T40! 1500
# send_text #10P761T40! 761
# send_text #11P1948T40! 1948
# send_text #12P1500T40! 1500
# setp_count: 60 130 160
# send_text #1P2233T40! 2233
# send_text #2P1049T40! 1049
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1950T40! 1950
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1050T40! 1050
# send_text #9P1500T40! 1500
# send_text #10P767T40! 767
# send_text #11P1951T40! 1951
# send_text #12P1500T40! 1500
# setp_count: 80 140 180
# send_text #1P2227T40! 2227
# send_text #2P1041T40! 1041
# send_text #3P1500T40! 1500
# send_text #4P755T40! 755
# send_text #5P1921T40! 1921
# send_text #6P1500T40! 1500
# send_text #7P2245T40! 2245
# send_text #8P1079T40! 1079
# send_text #9P1500T40! 1500
# send_text #10P773T40! 773
# send_text #11P1959T40! 1959
# send_text #12P1500T40! 1500
# setp_count: 100 150 0
# send_text #1P2219T40! 2219
# send_text #2P1028T40! 1028
# send_text #3P1500T40! 1500
# send_text #4P773T40! 773
# send_text #5P1909T40! 1909
# send_text #6P1500T40! 1500
# send_text #7P2227T40! 2227
# send_text #8P1091T40! 1091
# send_text #9P1500T40! 1500
# send_text #10P781T40! 781
# send_text #11P1972T40! 1972
# send_text #12P1500T40! 1500
# setp_count: 120 160 20
# send_text #1P2226T40! 2226
# send_text #2P1005T40! 1005
# send_text #3P1500T40! 1500
# send_text #4P780T40! 780
# send_text #5P1914T40! 1914
# send_text #6P1500T40! 1500
# send_text #7P2220T40! 2220
# send_text #8P1086T40! 1086
# send_text #9P1500T40! 1500
# send_text #10P774T40! 774
# send_text #11P1995T40! 1995
# send_text #12P1500T40! 1500
# setp_count: 140 170 40
# send_text #1P2238T40! 2238
# send_text #2P1017T40! 1017
# send_text #3P1500T40! 1500
# send_text #4P787T40! 787
# send_text #5P1925T40! 1925
# send_text #6P1500T40! 1500
# send_text #7P2213T40! 2213
# send_text #8P1075T40! 1075
# send_text #9P1500T40! 1500
# send_text #10P762T40! 762
# send_text #11P1983T40! 1983
# send_text #12P1500T40! 1500
# setp_count: 160 180 60
# send_text #1P2248T40! 2248
# send_text #2P1062T40! 1062
# send_text #3P1500T40! 1500
# send_text #4P795T40! 795
# send_text #5P1940T40! 1940
# send_text #6P1500T40! 1500
# send_text #7P2205T40! 2205
# send_text #8P1060T40! 1060
# send_text #9P1500T40! 1500
# send_text #10P752T40! 752
# send_text #11P1938T40! 1938
# send_text #12P1500T40! 1500
# setp_count: 180 190 80
# send_text #1P2233T40! 2233
# send_text #2P1127T40! 1127
# send_text #3P1500T40! 1500
# send_text #4P804T40! 804
# send_text #5P1959T40! 1959
# send_text #6P1500T40! 1500
# send_text #7P2196T40! 2196
# send_text #8P1041T40! 1041
# send_text #9P1500T40! 1500
# send_text #10P767T40! 767
# send_text #11P1873T40! 1873
# send_text #12P1500T40! 1500
# setp_count: 0 0 100
# send_text #1P2199T40! 2199
# send_text #2P1141T40! 1141
# send_text #3P1500T40! 1500
# send_text #4P818T40! 818
# send_text #5P1981T40! 1981
# send_text #6P1500T40! 1500
# send_text #7P2182T40! 2182
# send_text #8P1019T40! 1019
# send_text #9P1500T40! 1500
# send_text #10P801T40! 801
# send_text #11P1859T40! 1859
# send_text #12P1500T40! 1500
# setp_count: 20 10 120
# send_text #1P2193T40! 2193
# send_text #2P1121T40! 1121
# send_text #3P1500T40! 1500
# send_text #4P803T40! 803
# send_text #5P2018T40! 2018
# send_text #6P1500T40! 1500
# send_text #7P2197T40! 2197
# send_text #8P982T40! 982
# send_text #9P1500T40! 1500
# send_text #10P807T40! 807
# send_text #11P1879T40! 1879
# send_text #12P1500T40! 1500
# setp_count: 40 20 140
# send_text #1P2197T40! 2197
# send_text #2P1089T40! 1089
# send_text #3P1500T40! 1500
# send_text #4P768T40! 768
# send_text #5P1993T40! 1993
# send_text #6P1500T40! 1500
# send_text #7P2232T40! 2232
# send_text #8P1007T40! 1007
# send_text #9P1500T40! 1500
# send_text #10P803T40! 803
# send_text #11P1911T40! 1911
# send_text #12P1500T40! 1500
# setp_count: 60 30 160
# send_text #1P2194T40! 2194
# send_text #2P1065T40! 1065
# send_text #3P1500T40! 1500
# send_text #4P752T40! 752
# send_text #5P1933T40! 1933
# send_text #6P1500T40! 1500
# send_text #7P2248T40! 2248
# send_text #8P1067T40! 1067
# send_text #9P1500T40! 1500
# send_text #10P806T40! 806
# send_text #11P1935T40! 1935
# send_text #12P1500T40! 1500
# setp_count: 80 40 180
# send_text #1P2189T40! 2189
# send_text #2P1041T40! 1041
# send_text #3P1500T40! 1500
# send_text #4P770T40! 770
# send_text #5P1863T40! 1863
# send_text #6P1500T40! 1500
# send_text #7P2230T40! 2230
# send_text #8P1137T40! 1137
# send_text #9P1500T40! 1500
# send_text #10P811T40! 811
# send_text #11P1959T40! 1959
# send_text #12P1500T40! 1500
# setp_count: 100 50 0
# send_text #1P2182T40! 2182
# send_text #2P1019T40! 1019
# send_text #3P1500T40! 1500
# send_text #4P801T40! 801
# send_text #5P1859T40! 1859
# send_text #6P1500T40! 1500
# send_text #7P2199T40! 2199
# send_text #8P1141T40! 1141
# send_text #9P1500T40! 1500
# send_text #10P818T40! 818
# send_text #11P1981T40! 1981
# send_text #12P1500T40! 1500
# setp_count: 120 60 20
# send_text #1P2203T40! 2203
# send_text #2P986T40! 986
# send_text #3P1500T40! 1500
# send_text #4P801T40! 801
# send_text #5P1886T40! 1886
# send_text #6P1500T40! 1500
# send_text #7P2199T40! 2199
# send_text #8P1114T40! 1114
# send_text #9P1500T40! 1500
# send_text #10P797T40! 797
# send_text #11P2014T40! 2014
# send_text #12P1500T40! 1500
# setp_count: 140 70 40
# send_text #1P2232T40! 2232
# send_text #2P1007T40! 1007
# send_text #3P1500T40! 1500
# send_text #4P803T40! 803
# send_text #5P1911T40! 1911
# send_text #6P1500T40! 1500
# send_text #7P2197T40! 2197
# send_text #8P1089T40! 1089
# send_text #9P1500T40! 1500
# send_text #10P768T40! 768
# send_text #11P1993T40! 1993
# send_text #12P1500T40! 1500
# setp_count: 160 80 60
# send_text #1P2248T40! 2248
# send_text #2P1067T40! 1067
# send_text #3P1500T40! 1500
# send_text #4P806T40! 806
# send_text #5P1935T40! 1935
# send_text #6P1500T40! 1500
# send_text #7P2194T40! 2194
# send_text #8P1065T40! 1065
# send_text #9P1500T40! 1500
# send_text #10P752T40! 752
# send_text #11P1933T40! 1933
# send_text #12P1500T40! 1500
# setp_count: 180 90 80
# send_text #1P2230T40! 2230
# send_text #2P1137T40! 1137
# send_text #3P1500T40! 1500
# send_text #4P811T40! 811
# send_text #5P1959T40! 1959
# send_text #6P1500T40! 1500
# send_text #7P2189T40! 2189
# send_text #8P1041T40! 1041
# send_text #9P1500T40! 1500
# send_text #10P770T40! 770
# send_text #11P1863T40! 1863
# send_text #12P1500T40! 1500
# setp_count: 1 100 101
# send_text #1P2199T40! 2199
# send_text #2P1139T40! 1139
# send_text #3P1500T40! 1500
# send_text #4P818T40! 818
# send_text #5P1983T40! 1983
# send_text #6P1500T40! 1500
# send_text #7P2182T40! 2182
# send_text #8P1017T40! 1017
# send_text #9P1500T40! 1500
# send_text #10P801T40! 801
# send_text #11P1861T40! 1861
# send_text #12P1500T40! 1500
# setp_count: 21 110 121
# send_text #1P2199T40! 2199
# send_text #2P1113T40! 1113
# send_text #3P1500T40! 1500
# send_text #4P795T40! 795
# send_text #5P2015T40! 2015
# send_text #6P1500T40! 1500
# send_text #7P2205T40! 2205
# send_text #8P985T40! 985
# send_text #9P1500T40! 1500
# send_text #10P801T40! 801
# send_text #11P1887T40! 1887
# send_text #12P1500T40! 1500
# setp_count: 41 120 141
# send_text #1P2197T40! 2197
# send_text #2P1088T40! 1088
# send_text #3P1500T40! 1500
# send_text #4P767T40! 767
# send_text #5P1990T40! 1990
# send_text #6P1500T40! 1500
# send_text #7P2233T40! 2233
# send_text #8P1010T40! 1010
# send_text #9P1500T40! 1500
# send_text #10P803T40! 803
# send_text #11P1912T40! 1912
# send_text #12P1500T40! 1500
# setp_count: 61 130 161
# send_text #1P2194T40! 2194
# send_text #2P1063T40! 1063
# send_text #3P1500T40! 1500
# send_text #4P752T40! 752
# send_text #5P1929T40! 1929
# send_text #6P1500T40! 1500
# send_text #7P2248T40! 2248
# send_text #8P1071T40! 1071
# send_text #9P1500T40! 1500
# send_text #10P806T40! 806
# send_text #11P1937T40! 1937
# send_text #12P1500T40! 1500
# setp_count: 81 140 181
# send_text #1P2189T40! 2189
# send_text #2P1040T40! 1040
# send_text #3P1500T40! 1500
# send_text #4P772T40! 772
# send_text #5P1861T40! 1861
# send_text #6P1500T40! 1500
# send_text #7P2228T40! 2228
# send_text #8P1139T40! 1139
# send_text #9P1500T40! 1500
# send_text #10P811T40! 811
# send_text #11P1960T40! 1960
# send_text #12P1500T40! 1500
# setp_count: 101 150 1
# send_text #1P2182T40! 2182
# send_text #2P1017T40! 1017
# send_text #3P1500T40! 1500
# send_text #4P801T40! 801
# send_text #5P1861T40! 1861
# send_text #6P1500T40! 1500
# send_text #7P2199T40! 2199
# send_text #8P1139T40! 1139
# send_text #9P1500T40! 1500
# send_text #10P818T40! 818
# send_text #11P1983T40! 1983
# send_text #12P1500T40! 1500
# setp_count: 121 160 21
# send_text #1P2205T40! 2205
# send_text #2P985T40! 985
# send_text #3P1500T40! 1500
# send_text #4P801T40! 801
# send_text #5P1887T40! 1887
# send_text #6P1500T40! 1500
# send_text #7P2199T40! 2199
# send_text #8P1113T40! 1113
# send_text #9P1500T40! 1500
# send_text #10P795T40! 795
# send_text #11P2015T40! 2015
# send_text #12P1500T40! 1500
# setp_count: 141 170 41
# send_text #1P2233T40! 2233
# send_text #2P1010T40! 1010
# send_text #3P1500T40! 1500
# send_text #4P803T40! 803
# send_text #5P1912T40! 1912
# send_text #6P1500T40! 1500
# send_text #7P2197T40! 2197
# send_text #8P1088T40! 1088
# send_text #9P1500T40! 1500
# send_text #10P767T40! 767
# send_text #11P1990T40! 1990
# send_text #12P1500T40! 1500
# setp_count: 161 180 61
# send_text #1P2248T40! 2248
# send_text #2P1071T40! 1071
# send_text #3P1500T40! 1500
# send_text #4P806T40! 806
# send_text #5P1937T40! 1937
# send_text #6P1500T40! 1500
# send_text #7P2194T40! 2194
# send_text #8P1063T40! 1063
# send_text #9P1500T40! 1500
# send_text #10P752T40! 752
# send_text #11P1929T40! 1929
# send_text #12P1500T40! 1500
# setp_count: 181 190 81
# send_text #1P2228T40! 2228
# send_text #2P1139T40! 1139
# send_text #3P1500T40! 1500
# send_text #4P811T40! 811
# send_text #5P1960T40! 1960
# send_text #6P1500T40! 1500
# send_text #7P2189T40! 2189
# send_text #8P1040T40! 1040
# send_text #9P1500T40! 1500
# send_text #10P772T40! 772
# send_text #11P1861T40! 1861
# send_text #12P1500T40! 1500
# setp_count: 1 0 101
# send_text #1P2199T40! 2199
# send_text #2P1139T40! 1139
# send_text #3P1500T40! 1500
# send_text #4P818T40! 818
# send_text #5P1983T40! 1983
# send_text #6P1500T40! 1500
# send_text #7P2182T40! 2182
# send_text #8P1017T40! 1017
# send_text #9P1500T40! 1500
# send_text #10P801T40! 801
# send_text #11P1861T40! 1861
# send_text #12P1500T40! 1500
# setp_count: 21 10 121
# send_text #1P2199T40! 2199
# send_text #2P1113T40! 1113
# send_text #3P1500T40! 1500
# send_text #4P795T40! 795
# send_text #5P2015T40! 2015
# send_text #6P1500T40! 1500
# send_text #7P2205T40! 2205
# send_text #8P985T40! 985
# send_text #9P1500T40! 1500
# send_text #10P801T40! 801
# send_text #11P1887T40! 1887
# send_text #12P1500T40! 1500
# setp_count: 41 20 141
# send_text #1P2197T40! 2197
# send_text #2P1088T40! 1088
# send_text #3P1500T40! 1500
# send_text #4P767T40! 767
# send_text #5P1990T40! 1990
# send_text #6P1500T40! 1500
# send_text #7P2233T40! 2233
# send_text #8P1010T40! 1010
# send_text #9P1500T40! 1500
# send_text #10P803T40! 803
# send_text #11P1912T40! 1912
# send_text #12P1500T40! 1500
# setp_count: 61 30 161
# send_text #1P2194T40! 2194
# send_text #2P1063T40! 1063
# send_text #3P1500T40! 1500
# send_text #4P752T40! 752
# send_text #5P1929T40! 1929
# send_text #6P1500T40! 1500
# send_text #7P2248T40! 2248
# send_text #8P1071T40! 1071
# send_text #9P1500T40! 1500
# send_text #10P806T40! 806
# send_text #11P1937T40! 1937
# send_text #12P1500T40! 1500
# setp_count: 81 40 181
# send_text #1P2189T40! 2189
# send_text #2P1040T40! 1040
# send_text #3P1500T40! 1500
# send_text #4P772T40! 772
# send_text #5P1861T40! 1861
# send_text #6P1500T40! 1500
# send_text #7P2228T40! 2228
# send_text #8P1139T40! 1139
# send_text #9P1500T40! 1500
# send_text #10P811T40! 811
# send_text #11P1960T40! 1960
# send_text #12P1500T40! 1500
# setp_count: 101 50 1
# send_text #1P2182T40! 2182
# send_text #2P1017T40! 1017
# send_text #3P1500T40! 1500
# send_text #4P801T40! 801
# send_text #5P1861T40! 1861
# send_text #6P1500T40! 1500
# send_text #7P2199T40! 2199
# send_text #8P1139T40! 1139
# send_text #9P1500T40! 1500
# send_text #10P818T40! 818
# send_text #11P1983T40! 1983
# send_text #12P1500T40! 1500
# setp_count: 121 60 21
# send_text #1P2205T40! 2205
# send_text #2P985T40! 985
# send_text #3P1500T40! 1500
# send_text #4P801T40! 801
# send_text #5P1887T40! 1887
# send_text #6P1500T40! 1500
# send_text #7P2199T40! 2199
# send_text #8P1113T40! 1113
# send_text #9P1500T40! 1500
# send_text #10P795T40! 795
# send_text #11P2015T40! 2015
# send_text #12P1500T40! 1500
# setp_count: 141 70 41
# send_text #1P2233T40! 2233
# send_text #2P1010T40! 1010
# send_text #3P1500T40! 1500
# send_text #4P803T40! 803
# send_text #5P1912T40! 1912
# send_text #6P1500T40! 1500
# send_text #7P2197T40! 2197
# send_text #8P1088T40! 1088
# send_text #9P1500T40! 1500
# send_text #10P767T40! 767
# send_text #11P1990T40! 1990
# send_text #12P1500T40! 1500
# setp_count: 161 80 61
# send_text #1P2248T40! 2248
# send_text #2P1071T40! 1071
# send_text #3P1500T40! 1500
# send_text #4P806T40! 806
# send_text #5P1937T40! 1937
# send_text #6P1500T40! 1500
# send_text #7P2194T40! 2194
# send_text #8P1063T40! 1063
# send_text #9P1500T40! 1500
# send_text #10P752T40! 752
# send_text #11P1929T40! 1929
# send_text #12P1500T40! 1500
# setp_count: 181 90 81
# send_text #1P2228T40! 2228
# send_text #2P1139T40! 1139
# send_text #3P1500T40! 1500
# send_text #4P811T40! 811
# send_text #5P1960T40! 1960
# send_text #6P1500T40! 1500
# send_text #7P2189T40! 2189
# send_text #8P1040T40! 1040
# send_text #9P1500T40! 1500
# send_text #10P772T40! 772
# send_text #11P1861T40! 1861
# send_text #12P1500T40! 1500
# setp_count: 2 101 102
# send_text #1P2199T40! 2199
# send_text #2P1138T40! 1138
# send_text #3P1500T40! 1500
# send_text #4P818T40! 818
# send_text #5P1986T40! 1986
# send_text #6P1500T40! 1500
# send_text #7P2182T40! 2182
# send_text #8P1014T40! 1014
# send_text #9P1500T40! 1500
# send_text #10P801T40! 801
# send_text #11P1862T40! 1862
# send_text #12P1500T40! 1500
# setp_count: 22 111 122
# send_text #1P2199T40! 2199
# send_text #2P1112T40! 1112
# send_text #3P1500T40! 1500
# send_text #4P794T40! 794
# send_text #5P2015T40! 2015
# send_text #6P1500T40! 1500
# send_text #7P2206T40! 2206
# send_text #8P985T40! 985
# send_text #9P1500T40! 1500
# send_text #10P801T40! 801
# send_text #11P1888T40! 1888
# send_text #12P1500T40! 1500
# setp_count: 42 121 142
# send_text #1P2197T40! 2197
# send_text #2P1086T40! 1086
# send_text #3P1500T40! 1500
# send_text #4P766T40! 766
# send_text #5P1988T40! 1988
# send_text #6P1500T40! 1500
# send_text #7P2234T40! 2234
# send_text #8P1012T40! 1012
# send_text #9P1500T40! 1500
# send_text #10P803T40! 803
# send_text #11P1914T40! 1914
# send_text #12P1500T40! 1500
# setp_count: 62 131 162
# send_text #1P2194T40! 2194
# send_text #2P1062T40! 1062
# send_text #3P1500T40! 1500
# send_text #4P752T40! 752
# send_text #5P1925T40! 1925
# send_text #6P1500T40! 1500
# send_text #7P2248T40! 2248
# send_text #8P1075T40! 1075
# send_text #9P1500T40! 1500
# send_text #10P806T40! 806
# send_text #11P1938T40! 1938
# send_text #12P1500T40! 1500
# setp_count: 82 141 182
# send_text #1P2189T40! 2189
# send_text #2P1039T40! 1039
# send_text #3P1500T40! 1500
# send_text #4P774T40! 774
# send_text #5P1858T40! 1858
# send_text #6P1500T40! 1500
# send_text #7P2226T40! 2226
# send_text #8P1142T40! 1142
# send_text #9P1500T40! 1500
# send_text #10P811T40! 811
# send_text #11P1961T40! 1961
# send_text #12P1500T40! 1500
# setp_count: 102 151 2
# send_text #1P2182T40! 2182
# send_text #2P1014T40! 1014
# send_text #3P1500T40! 1500
# send_text #4P801T40! 801
# send_text #5P1862T40! 1862
# send_text #6P1500T40! 1500
# send_text #7P2199T40! 2199
# send_text #8P1138T40! 1138
# send_text #9P1500T40! 1500
# send_text #10P818T40! 818
# send_text #11P1986T40! 1986
# send_text #12P1500T40! 1500
# setp_count: 122 161 22
# send_text #1P2206T40! 2206
# send_text #2P985T40! 985
# send_text #3P1500T40! 1500
# send_text #4P801T40! 801
# send_text #5P1888T40! 1888
# send_text #6P1500T40! 1500
# send_text #7P2199T40! 2199
# send_text #8P1112T40! 1112
# send_text #9P1500T40! 1500
# send_text #10P794T40! 794
# send_text #11P2015T40! 2015
# send_text #12P1500T40! 1500
# setp_count: 142 171 42
# send_text #1P2234T40! 2234
# send_text #2P1012T40! 1012
# send_text #3P1500T40! 1500
# send_text #4P803T40! 803
# send_text #5P1914T40! 1914
# send_text #6P1500T40! 1500
# send_text #7P2197T40! 2197
# send_text #8P1086T40! 1086
# send_text #9P1500T40! 1500
# send_text #10P766T40! 766
# send_text #11P1988T40! 1988
# send_text #12P1500T40! 1500
# setp_count: 162 181 62
# send_text #1P2248T40! 2248
# send_text #2P1075T40! 1075
# send_text #3P1500T40! 1500
# send_text #4P806T40! 806
# send_text #5P1938T40! 1938
# send_text #6P1500T40! 1500
# send_text #7P2194T40! 2194
# send_text #8P1062T40! 1062
# send_text #9P1500T40! 1500
# send_text #10P752T40! 752
# send_text #11P1925T40! 1925
# send_text #12P1500T40! 1500
# setp_count: 182 191 82
# send_text #1P2226T40! 2226
# send_text #2P1142T40! 1142
# send_text #3P1500T40! 1500
# send_text #4P811T40! 811
# send_text #5P1961T40! 1961
# send_text #6P1500T40! 1500
# send_text #7P2189T40! 2189
# send_text #8P1039T40! 1039
# send_text #9P1500T40! 1500
# send_text #10P774T40! 774
# send_text #11P1858T40! 1858
# send_text #12P1500T40! 1500
# setp_count: 2 1 102
# send_text #1P2199T40! 2199
# send_text #2P1138T40! 1138
# send_text #3P1500T40! 1500
# send_text #4P818T40! 818
# send_text #5P1986T40! 1986
# send_text #6P1500T40! 1500
# send_text #7P2182T40! 2182
# send_text #8P1014T40! 1014
# send_text #9P1500T40! 1500
# send_text #10P801T40! 801
# send_text #11P1862T40! 1862
# send_text #12P1500T40! 1500
# setp_count: 22 11 122
# send_text #1P2199T40! 2199
# send_text #2P1112T40! 1112
# send_text #3P1500T40! 1500
# send_text #4P794T40! 794
# send_text #5P2015T40! 2015
# send_text #6P1500T40! 1500
# send_text #7P2206T40! 2206
# send_text #8P985T40! 985
# send_text #9P1500T40! 1500
# send_text #10P801T40! 801
# send_text #11P1888T40! 1888
# send_text #12P1500T40! 1500
# setp_count: 42 21 142
# send_text #1P2197T40! 2197
# send_text #2P1086T40! 1086
# send_text #3P1500T40! 1500
# send_text #4P766T40! 766
# send_text #5P1988T40! 1988
# send_text #6P1500T40! 1500
# send_text #7P2234T40! 2234
# send_text #8P1012T40! 1012
# send_text #9P1500T40! 1500
# send_text #10P803T40! 803
# send_text #11P1914T40! 1914
# send_text #12P1500T40! 1500
# setp_count: 62 31 162
# send_text #1P2194T40! 2194
# send_text #2P1062T40! 1062
# send_text #3P1500T40! 1500
# send_text #4P752T40! 752
# send_text #5P1925T40! 1925
# send_text #6P1500T40! 1500
# send_text #7P2248T40! 2248
# send_text #8P1075T40! 1075
# send_text #9P1500T40! 1500
# send_text #10P806T40! 806
# send_text #11P1938T40! 1938
# send_text #12P1500T40! 1500
# setp_count: 82 41 182
# send_text #1P2189T40! 2189
# send_text #2P1039T40! 1039
# send_text #3P1500T40! 1500
# send_text #4P774T40! 774
# send_text #5P1858T40! 1858
# send_text #6P1500T40! 1500
# send_text #7P2226T40! 2226
# send_text #8P1142T40! 1142
# send_text #9P1500T40! 1500
# send_text #10P811T40! 811
# send_text #11P1961T40! 1961
# send_text #12P1500T40! 1500
# setp_count: 102 51 2
# send_text #1P2182T40! 2182
# send_text #2P1014T40! 1014
# send_text #3P1500T40! 1500
# send_text #4P801T40! 801
# send_text #5P1862T40! 1862
# send_text #6P1500T40! 1500
# send_text #7P2199T40! 2199
# send_text #8P1138T40! 1138
# send_text #9P1500T40! 1500
# send_text #10P818T40! 818
# send_text #11P1986T40! 1986
# send_text #12P1500T40! 1500
# setp_count: 122 61 22
# send_text #1P2206T40! 2206
# send_text #2P985T40! 985
# send_text #3P1500T40! 1500
# send_text #4P801T40! 801
# send_text #5P1888T40! 1888
# send_text #6P1500T40! 1500
# send_text #7P2199T40! 2199
# send_text #8P1112T40! 1112
# send_text #9P1500T40! 1500
# send_text #10P794T40! 794
# send_text #11P2015T40! 2015
# send_text #12P1500T40! 1500
# setp_count: 142 71 42
# send_text #1P2234T40! 2234
# send_text #2P1012T40! 1012
# send_text #3P1500T40! 1500
# send_text #4P803T40! 803
# send_text #5P1914T40! 1914
# send_text #6P1500T40! 1500
# send_text #7P2197T40! 2197
# send_text #8P1086T40! 1086
# send_text #9P1500T40! 1500
# send_text #10P766T40! 766
# send_text #11P1988T40! 1988
# send_text #12P1500T40! 1500
# setp_count: 162 81 62
# send_text #1P2248T40! 2248
# send_text #2P1075T40! 1075
# send_text #3P1500T40! 1500
# send_text #4P806T40! 806
# send_text #5P1938T40! 1938
# send_text #6P1500T40! 1500
# send_text #7P2194T40! 2194
# send_text #8P1062T40! 1062
# send_text #9P1500T40! 1500
# send_text #10P752T40! 752
# send_text #11P1925T40! 1925
# send_text #12P1500T40! 1500
# setp_count: 182 91 82
# send_text #1P2226T40! 2226
# send_text #2P1142T40! 1142
# send_text #3P1500T40! 1500
# send_text #4P811T40! 811
# send_text #5P1961T40! 1961
# send_text #6P1500T40! 1500
# send_text #7P2189T40! 2189
# send_text #8P1039T40! 1039
# send_text #9P1500T40! 1500
# send_text #10P774T40! 774
# send_text #11P1858T40! 1858
# send_text #12P1500T40! 1500
# setp_count: 3 101 103
# send_text #1P2199T40! 2199
# send_text #2P1137T40! 1137
# send_text #3P1500T40! 1500
# send_text #4P818T40! 818
# send_text #5P1988T40! 1988
# send_text #6P1500T40! 1500
# send_text #7P2182T40! 2182
# send_text #8P1012T40! 1012
# send_text #9P1500T40! 1500
# send_text #10P801T40! 801
# send_text #11P1863T40! 1863
# send_text #12P1500T40! 1500
# setp_count: 23 111 123
# send_text #1P2199T40! 2199
# send_text #2P1110T40! 1110
# send_text #3P1500T40! 1500
# send_text #4P793T40! 793
# send_text #5P2015T40! 2015
# send_text #6P1500T40! 1500
# send_text #7P2207T40! 2207
# send_text #8P985T40! 985
# send_text #9P1500T40! 1500
# send_text #10P801T40! 801
# send_text #11P1890T40! 1890
# send_text #12P1500T40! 1500
# setp_count: 43 121 143
# send_text #1P2197T40! 2197
# send_text #2P1085T40! 1085
# send_text #3P1500T40! 1500
# send_text #4P764T40! 764
# send_text #5P1985T40! 1985
# send_text #6P1500T40! 1500
# send_text #7P2236T40! 2236
# send_text #8P1015T40! 1015
# send_text #9P1500T40! 1500
# send_text #10P803T40! 803
# send_text #11P1915T40! 1915
# send_text #12P1500T40! 1500
# setp_count: 63 131 163
# send_text #1P2193T40! 2193
# send_text #2P1061T40! 1061
# send_text #3P1500T40! 1500
# send_text #4P752T40! 752
# send_text #5P1922T40! 1922
# send_text #6P1500T40! 1500
# send_text #7P2248T40! 2248
# send_text #8P1078T40! 1078
# send_text #9P1500T40! 1500
# send_text #10P807T40! 807
# send_text #11P1939T40! 1939
# send_text #12P1500T40! 1500
# setp_count: 83 141 183
# send_text #1P2189T40! 2189
# send_text #2P1038T40! 1038
# send_text #3P1500T40! 1500
# send_text #4P776T40! 776
# send_text #5P1856T40! 1856
# send_text #6P1500T40! 1500
# send_text #7P2224T40! 2224
# send_text #8P1144T40! 1144
# send_text #9P1500T40! 1500
# send_text #10P811T40! 811
# send_text #11P1962T40! 1962
# send_text #12P1500T40! 1500
# setp_count: 103 151 3
# send_text #1P2182T40! 2182
# send_text #2P1012T40! 1012
# send_text #3P1500T40! 1500
# send_text #4P801T40! 801
# send_text #5P1863T40! 1863
# send_text #6P1500T40! 1500
# send_text #7P2199T40! 2199
# send_text #8P1137T40! 1137
# send_text #9P1500T40! 1500
# send_text #10P818T40! 818
# send_text #11P1988T40! 1988
# send_text #12P1500T40! 1500
# setp_count: 123 161 23
# send_text #1P2207T40! 2207
# send_text #2P985T40! 985
# send_text #3P1500T40! 1500
# send_text #4P801T40! 801
# send_text #5P1890T40! 1890
# send_text #6P1500T40! 1500
# send_text #7P2199T40! 2199
# send_text #8P1110T40! 1110
# send_text #9P1500T40! 1500
# send_text #10P793T40! 793
# send_text #11P2015T40! 2015
# send_text #12P1500T40! 1500
# setp_count: 143 171 43
# send_text #1P2236T40! 2236
# send_text #2P1015T40! 1015
# send_text #3P1500T40! 1500
# send_text #4P803T40! 803
# send_text #5P1915T40! 1915
# send_text #6P1500T40! 1500
# send_text #7P2197T40! 2197
# send_text #8P1085T40! 1085
# send_text #9P1500T40! 1500
# send_text #10P764T40! 764
# send_text #11P1985T40! 1985
# send_text #12P1500T40! 1500
# setp_count: 163 181 63
# send_text #1P2248T40! 2248
# send_text #2P1078T40! 1078
# send_text #3P1500T40! 1500
# send_text #4P807T40! 807
# send_text #5P1939T40! 1939
# send_text #6P1500T40! 1500
# send_text #7P2193T40! 2193
# send_text #8P1061T40! 1061
# send_text #9P1500T40! 1500
# send_text #10P752T40! 752
# send_text #11P1922T40! 1922
# send_text #12P1500T40! 1500
# setp_count: 183 191 83
# send_text #1P2224T40! 2224
# send_text #2P1144T40! 1144
# send_text #3P1500T40! 1500
# send_text #4P811T40! 811
# send_text #5P1962T40! 1962
# send_text #6P1500T40! 1500
# send_text #7P2189T40! 2189
# send_text #8P1038T40! 1038
# send_text #9P1500T40! 1500
# send_text #10P776T40! 776
# send_text #11P1856T40! 1856
# send_text #12P1500T40! 1500
# setp_count: 3 1 103
# send_text #1P2199T40! 2199
# send_text #2P1137T40! 1137
# send_text #3P1500T40! 1500
# send_text #4P818T40! 818
# send_text #5P1988T40! 1988
# send_text #6P1500T40! 1500
# send_text #7P2182T40! 2182
# send_text #8P1012T40! 1012
# send_text #9P1500T40! 1500
# send_text #10P801T40! 801
# send_text #11P1863T40! 1863
# send_text #12P1500T40! 1500
# setp_count: 23 11 123
# send_text #1P2199T40! 2199
# send_text #2P1110T40! 1110
# send_text #3P1500T40! 1500
# send_text #4P793T40! 793
# send_text #5P2015T40! 2015
# send_text #6P1500T40! 1500
# send_text #7P2207T40! 2207
# send_text #8P985T40! 985
# send_text #9P1500T40! 1500
# send_text #10P801T40! 801
# send_text #11P1890T40! 1890
# send_text #12P1500T40! 1500
# setp_count: 43 21 143
# send_text #1P2197T40! 2197
# send_text #2P1085T40! 1085
# send_text #3P1500T40! 1500
# send_text #4P764T40! 764
# send_text #5P1985T40! 1985
# send_text #6P1500T40! 1500
# send_text #7P2236T40! 2236
# send_text #8P1015T40! 1015
# send_text #9P1500T40! 1500
# send_text #10P803T40! 803
# send_text #11P1915T40! 1915
# send_text #12P1500T40! 1500
# setp_count: 63 31 163
# send_text #1P2193T40! 2193
# send_text #2P1061T40! 1061
# send_text #3P1500T40! 1500
# send_text #4P752T40! 752
# send_text #5P1922T40! 1922
# send_text #6P1500T40! 1500
# send_text #7P2248T40! 2248
# send_text #8P1078T40! 1078
# send_text #9P1500T40! 1500
# send_text #10P807T40! 807
# send_text #11P1939T40! 1939
# send_text #12P1500T40! 1500
# setp_count: 83 41 183
# send_text #1P2189T40! 2189
# send_text #2P1038T40! 1038
# send_text #3P1500T40! 1500
# send_text #4P776T40! 776
# send_text #5P1856T40! 1856
# send_text #6P1500T40! 1500
# send_text #7P2224T40! 2224
# send_text #8P1144T40! 1144
# send_text #9P1500T40! 1500
# send_text #10P811T40! 811
# send_text #11P1962T40! 1962
# send_text #12P1500T40! 1500
# setp_count: 103 51 3
# send_text #1P2182T40! 2182
# send_text #2P1012T40! 1012
# send_text #3P1500T40! 1500
# send_text #4P801T40! 801
# send_text #5P1863T40! 1863
# send_text #6P1500T40! 1500
# send_text #7P2199T40! 2199
# send_text #8P1137T40! 1137
# send_text #9P1500T40! 1500
# send_text #10P818T40! 818
# send_text #11P1988T40! 1988
# send_text #12P1500T40! 1500
# setp_count: 123 61 23
# send_text #1P2207T40! 2207
# send_text #2P985T40! 985
# send_text #3P1500T40! 1500
# send_text #4P801T40! 801
# send_text #5P1890T40! 1890
# send_text #6P1500T40! 1500
# send_text #7P2199T40! 2199
# send_text #8P1110T40! 1110
# send_text #9P1500T40! 1500
# send_text #10P793T40! 793
# send_text #11P2015T40! 2015
# send_text #12P1500T40! 1500
# setp_count: 143 71 43
# send_text #1P2236T40! 2236
# send_text #2P1015T40! 1015
# send_text #3P1500T40! 1500
# send_text #4P803T40! 803
# send_text #5P1915T40! 1915
# send_text #6P1500T40! 1500
# send_text #7P2197T40! 2197
# send_text #8P1085T40! 1085
# send_text #9P1500T40! 1500
# send_text #10P764T40! 764
# send_text #11P1985T40! 1985
# send_text #12P1500T40! 1500
# setp_count: 163 81 63
# send_text #1P2248T40! 2248
# send_text #2P1078T40! 1078
# send_text #3P1500T40! 1500
# send_text #4P807T40! 807
# send_text #5P1939T40! 1939
# send_text #6P1500T40! 1500
# send_text #7P2193T40! 2193
# send_text #8P1061T40! 1061
# send_text #9P1500T40! 1500
# send_text #10P752T40! 752
# send_text #11P1922T40! 1922
# send_text #12P1500T40! 1500
# setp_count: 183 91 83
# send_text #1P2224T40! 2224
# send_text #2P1144T40! 1144
# send_text #3P1500T40! 1500
# send_text #4P811T40! 811
# send_text #5P1962T40! 1962
# send_text #6P1500T40! 1500
# send_text #7P2189T40! 2189
# send_text #8P1038T40! 1038
# send_text #9P1500T40! 1500
# send_text #10P776T40! 776
# send_text #11P1856T40! 1856
# send_text #12P1500T40! 1500
# setp_count: 4 102 104
# send_text #1P2199T40! 2199
# send_text #2P1135T40! 1135
# send_text #3P1500T40! 1500
# send_text #4P817T40! 817
# send_text #5P1990T40! 1990
# send_text #6P1500T40! 1500
# send_text #7P2183T40! 2183
# send_text #8P1010T40! 1010
# send_text #9P1500T40! 1500
# send_text #10P801T40! 801
# send_text #11P1865T40! 1865
# send_text #12P1500T40! 1500
# setp_count: 24 112 124
# send_text #1P2199T40! 2199
# send_text #2P1109T40! 1109
# send_text #3P1500T40! 1500
# send_text #4P791T40! 791
# send_text #5P2015T40! 2015
# send_text #6P1500T40! 1500
# send_text #7P2209T40! 2209
# send_text #8P985T40! 985
# send_text #9P1500T40! 1500
# send_text #10P801T40! 801
# send_text #11P1891T40! 1891
# send_text #12P1500T40! 1500
# setp_count: 44 122 144
# send_text #1P2197T40! 2197
# send_text #2P1084T40! 1084
# send_text #3P1500T40! 1500
# send_text #4P763T40! 763
# send_text #5P1983T40! 1983
# send_text #6P1500T40! 1500
# send_text #7P2237T40! 2237
# send_text #8P1017T40! 1017
# send_text #9P1500T40! 1500
# send_text #10P803T40! 803
# send_text #11P1916T40! 1916
# send_text #12P1500T40! 1500
# setp_count: 64 132 164
# send_text #1P2193T40! 2193
# send_text #2P1060T40! 1060
# send_text #3P1500T40! 1500
# send_text #4P753T40! 753
# send_text #5P1918T40! 1918
# send_text #6P1500T40! 1500
# send_text #7P2247T40! 2247
# send_text #8P1082T40! 1082
# send_text #9P1500T40! 1500
# send_text #10P807T40! 807
# send_text #11P1940T40! 1940
# send_text #12P1500T40! 1500
# setp_count: 84 142 184
# send_text #1P2188T40! 2188
# send_text #2P1037T40! 1037
# send_text #3P1500T40! 1500
# send_text #4P778T40! 778
# send_text #5P1854T40! 1854
# send_text #6P1500T40! 1500
# send_text #7P2222T40! 2222
# send_text #8P1146T40! 1146
# send_text #9P1500T40! 1500
# send_text #10P812T40! 812
# send_text #11P1963T40! 1963
# send_text #12P1500T40! 1500
# setp_count: 104 152 4
# send_text #1P2183T40! 2183
# send_text #2P1010T40! 1010
# send_text #3P1500T40! 1500
# send_text #4P801T40! 801
# send_text #5P1865T40! 1865
# send_text #6P1500T40! 1500
# send_text #7P2199T40! 2199
# send_text #8P1135T40! 1135
# send_text #9P1500T40! 1500
# send_text #10P817T40! 817
# send_text #11P1990T40! 1990
# send_text #12P1500T40! 1500
# setp_count: 124 162 24
# send_text #1P2209T40! 2209
# send_text #2P985T40! 985
# send_text #3P1500T40! 1500
# send_text #4P801T40! 801
# send_text #5P1891T40! 1891
# send_text #6P1500T40! 1500
# send_text #7P2199T40! 2199
# send_text #8P1109T40! 1109
# send_text #9P1500T40! 1500
# send_text #10P791T40! 791
# send_text #11P2015T40! 2015
# send_text #12P1500T40! 1500
# setp_count: 144 172 44
# send_text #1P2237T40! 2237
# send_text #2P1017T40! 1017
# send_text #3P1500T40! 1500
# send_text #4P803T40! 803
# send_text #5P1916T40! 1916
# send_text #6P1500T40! 1500
# send_text #7P2197T40! 2197
# send_text #8P1084T40! 1084
# send_text #9P1500T40! 1500
# send_text #10P763T40! 763
# send_text #11P1983T40! 1983
# send_text #12P1500T40! 1500
# setp_count: 164 182 64
# send_text #1P2247T40! 2247
# send_text #2P1082T40! 1082
# send_text #3P1500T40! 1500
# send_text #4P807T40! 807
# send_text #5P1940T40! 1940
# send_text #6P1500T40! 1500
# send_text #7P2193T40! 2193
# send_text #8P1060T40! 1060
# send_text #9P1500T40! 1500
# send_text #10P753T40! 753
# send_text #11P1918T40! 1918
# send_text #12P1500T40! 1500
# setp_count: 184 192 84
# send_text #1P2222T40! 2222
# send_text #2P1146T40! 1146
# send_text #3P1500T40! 1500
# send_text #4P812T40! 812
# send_text #5P1963T40! 1963
# send_text #6P1500T40! 1500
# send_text #7P2188T40! 2188
# send_text #8P1037T40! 1037
# send_text #9P1500T40! 1500
# send_text #10P778T40! 778
# send_text #11P1854T40! 1854
# send_text #12P1500T40! 1500
# setp_count: 4 2 104
# send_text #1P2199T40! 2199
# send_text #2P1135T40! 1135
# send_text #3P1500T40! 1500
# send_text #4P817T40! 817
# send_text #5P1990T40! 1990
# send_text #6P1500T40! 1500
# send_text #7P2183T40! 2183
# send_text #8P1010T40! 1010
# send_text #9P1500T40! 1500
# send_text #10P801T40! 801
# send_text #11P1865T40! 1865
# send_text #12P1500T40! 1500
# setp_count: 24 12 124
# send_text #1P2199T40! 2199
# send_text #2P1109T40! 1109
# send_text #3P1500T40! 1500
# send_text #4P791T40! 791
# send_text #5P2015T40! 2015
# send_text #6P1500T40! 1500
# send_text #7P2209T40! 2209
# send_text #8P985T40! 985
# send_text #9P1500T40! 1500
# send_text #10P801T40! 801
# send_text #11P1891T40! 1891
# send_text #12P1500T40! 1500
# setp_count: 44 22 144
# send_text #1P2197T40! 2197
# send_text #2P1084T40! 1084
# send_text #3P1500T40! 1500
# send_text #4P763T40! 763
# send_text #5P1983T40! 1983
# send_text #6P1500T40! 1500
# send_text #7P2237T40! 2237
# send_text #8P1017T40! 1017
# send_text #9P1500T40! 1500
# send_text #10P803T40! 803
# send_text #11P1916T40! 1916
# send_text #12P1500T40! 1500
# setp_count: 64 32 164
# send_text #1P2193T40! 2193
# send_text #2P1060T40! 1060
# send_text #3P1500T40! 1500
# send_text #4P753T40! 753
# send_text #5P1918T40! 1918
# send_text #6P1500T40! 1500
# send_text #7P2247T40! 2247
# send_text #8P1082T40! 1082
# send_text #9P1500T40! 1500
# send_text #10P807T40! 807
# send_text #11P1940T40! 1940
# send_text #12P1500T40! 1500
# setp_count: 84 42 184
# send_text #1P2188T40! 2188
# send_text #2P1037T40! 1037
# send_text #3P1500T40! 1500
# send_text #4P778T40! 778
# send_text #5P1854T40! 1854
# send_text #6P1500T40! 1500
# send_text #7P2222T40! 2222
# send_text #8P1146T40! 1146
# send_text #9P1500T40! 1500
# send_text #10P812T40! 812
# send_text #11P1963T40! 1963
# send_text #12P1500T40! 1500
# setp_count: 104 52 4
# send_text #1P2183T40! 2183
# send_text #2P1010T40! 1010
# send_text #3P1500T40! 1500
# send_text #4P801T40! 801
# send_text #5P1865T40! 1865
# send_text #6P1500T40! 1500
# send_text #7P2199T40! 2199
# send_text #8P1135T40! 1135
# send_text #9P1500T40! 1500
# send_text #10P817T40! 817
# send_text #11P1990T40! 1990
# send_text #12P1500T40! 1500
# setp_count: 124 62 24
# send_text #1P2209T40! 2209
# send_text #2P985T40! 985
# send_text #3P1500T40! 1500
# send_text #4P801T40! 801
# send_text #5P1891T40! 1891
# send_text #6P1500T40! 1500
# send_text #7P2199T40! 2199
# send_text #8P1109T40! 1109
# send_text #9P1500T40! 1500
# send_text #10P791T40! 791
# send_text #11P2015T40! 2015
# send_text #12P1500T40! 1500
# setp_count: 144 72 44
# send_text #1P2237T40! 2237
# send_text #2P1017T40! 1017
# send_text #3P1500T40! 1500
# send_text #4P803T40! 803
# send_text #5P1916T40! 1916
# send_text #6P1500T40! 1500
# send_text #7P2197T40! 2197
# send_text #8P1084T40! 1084
# send_text #9P1500T40! 1500
# send_text #10P763T40! 763
# send_text #11P1983T40! 1983
# send_text #12P1500T40! 1500
# setp_count: 164 82 64
# send_text #1P2247T40! 2247
# send_text #2P1082T40! 1082
# send_text #3P1500T40! 1500
# send_text #4P807T40! 807
# send_text #5P1940T40! 1940
# send_text #6P1500T40! 1500
# send_text #7P2193T40! 2193
# send_text #8P1060T40! 1060
# send_text #9P1500T40! 1500
# send_text #10P753T40! 753
# send_text #11P1918T40! 1918
# send_text #12P1500T40! 1500
# setp_count: 184 92 84
# send_text #1P2222T40! 2222
# send_text #2P1146T40! 1146
# send_text #3P1500T40! 1500
# send_text #4P812T40! 812
# send_text #5P1963T40! 1963
# send_text #6P1500T40! 1500
# send_text #7P2188T40! 2188
# send_text #8P1037T40! 1037
# send_text #9P1500T40! 1500
# send_text #10P778T40! 778
# send_text #11P1854T40! 1854
# send_text #12P1500T40! 1500
# setp_count: 5 102 105
# send_text #1P2199T40! 2199
# send_text #2P1134T40! 1134
# send_text #3P1500T40! 1500
# send_text #4P816T40! 816
# send_text #5P1992T40! 1992
# send_text #6P1500T40! 1500
# send_text #7P2184T40! 2184
# send_text #8P1008T40! 1008
# send_text #9P1500T40! 1500
# send_text #10P801T40! 801
# send_text #11P1866T40! 1866
# send_text #12P1500T40! 1500
# setp_count: 25 112 125
# send_text #1P2199T40! 2199
# send_text #2P1108T40! 1108
# send_text #3P1500T40! 1500
# send_text #4P790T40! 790
# send_text #5P2015T40! 2015
# send_text #6P1500T40! 1500
# send_text #7P2210T40! 2210
# send_text #8P985T40! 985
# send_text #9P1500T40! 1500
# send_text #10P801T40! 801
# send_text #11P1892T40! 1892
# send_text #12P1500T40! 1500
# setp_count: 45 122 145
# send_text #1P2196T40! 2196
# send_text #2P1083T40! 1083
# send_text #3P1500T40! 1500
# send_text #4P762T40! 762
# send_text #5P1980T40! 1980
# send_text #6P1500T40! 1500
# send_text #7P2238T40! 2238
# send_text #8P1020T40! 1020
# send_text #9P1500T40! 1500
# send_text #10P804T40! 804
# send_text #11P1917T40! 1917
# send_text #12P1500T40! 1500
# setp_count: 65 132 165
# send_text #1P2193T40! 2193
# send_text #2P1059T40! 1059
# send_text #3P1500T40! 1500
# send_text #4P753T40! 753
# send_text #5P1915T40! 1915
# send_text #6P1500T40! 1500
# send_text #7P2247T40! 2247
# send_text #8P1085T40! 1085
# send_text #9P1500T40! 1500
# send_text #10P807T40! 807
# send_text #11P1941T40! 1941
# send_text #12P1500T40! 1500
# setp_count: 85 142 185
# send_text #1P2188T40! 2188
# send_text #2P1036T40! 1036
# send_text #3P1500T40! 1500
# send_text #4P780T40! 780
# send_text #5P1853T40! 1853
# send_text #6P1500T40! 1500
# send_text #7P2220T40! 2220
# send_text #8P1147T40! 1147
# send_text #9P1500T40! 1500
# send_text #10P812T40! 812
# send_text #11P1964T40! 1964
# send_text #12P1500T40! 1500
# setp_count: 105 152 5
# send_text #1P2184T40! 2184
# send_text #2P1008T40! 1008
# send_text #3P1500T40! 1500
# send_text #4P801T40! 801
# send_text #5P1866T40! 1866
# send_text #6P1500T40! 1500
# send_text #7P2199T40! 2199
# send_text #8P1134T40! 1134
# send_text #9P1500T40! 1500
# send_text #10P816T40! 816
# send_text #11P1992T40! 1992
# send_text #12P1500T40! 1500
# setp_count: 125 162 25
# send_text #1P2210T40! 2210
# send_text #2P985T40! 985
# send_text #3P1500T40! 1500
# send_text #4P801T40! 801
# send_text #5P1892T40! 1892
# send_text #6P1500T40! 1500
# send_text #7P2199T40! 2199
# send_text #8P1108T40! 1108
# send_text #9P1500T40! 1500
# send_text #10P790T40! 790
# send_text #11P2015T40! 2015
# send_text #12P1500T40! 1500
# setp_count: 145 172 45
# send_text #1P2238T40! 2238
# send_text #2P1020T40! 1020
# send_text #3P1500T40! 1500
# send_text #4P804T40! 804
# send_text #5P1917T40! 1917
# send_text #6P1500T40! 1500
# send_text #7P2196T40! 2196
# send_text #8P1083T40! 1083
# send_text #9P1500T40! 1500
# send_text #10P762T40! 762
# send_text #11P1980T40! 1980
# send_text #12P1500T40! 1500
# setp_count: 165 182 65
# send_text #1P2247T40! 2247
# send_text #2P1085T40! 1085
# send_text #3P1500T40! 1500
# send_text #4P807T40! 807
# send_text #5P1941T40! 1941
# send_text #6P1500T40! 1500
# send_text #7P2193T40! 2193
# send_text #8P1059T40! 1059
# send_text #9P1500T40! 1500
# send_text #10P753T40! 753
# send_text #11P1915T40! 1915
# send_text #12P1500T40! 1500
# setp_count: 185 192 85
# send_text #1P2220T40! 2220
# send_text #2P1147T40! 1147
# send_text #3P1500T40! 1500
# send_text #4P812T40! 812
# send_text #5P1964T40! 1964
# send_text #6P1500T40! 1500
# send_text #7P2188T40! 2188
# send_text #8P1036T40! 1036
# send_text #9P1500T40! 1500
# send_text #10P780T40! 780
# send_text #11P1853T40! 1853
# send_text #12P1500T40! 1500
# setp_count: 5 2 105
# send_text #1P2199T40! 2199
# send_text #2P1134T40! 1134
# send_text #3P1500T40! 1500
# send_text #4P816T40! 816
# send_text #5P1992T40! 1992
# send_text #6P1500T40! 1500
# send_text #7P2184T40! 2184
# send_text #8P1008T40! 1008
# send_text #9P1500T40! 1500
# send_text #10P801T40! 801
# send_text #11P1866T40! 1866
# send_text #12P1500T40! 1500
# setp_count: 25 12 125
# send_text #1P2199T40! 2199
# send_text #2P1108T40! 1108
# send_text #3P1500T40! 1500
# send_text #4P790T40! 790
# send_text #5P2015T40! 2015
# send_text #6P1500T40! 1500
# send_text #7P2210T40! 2210
# send_text #8P985T40! 985
# send_text #9P1500T40! 1500
# send_text #10P801T40! 801
# send_text #11P1892T40! 1892
# send_text #12P1500T40! 1500
# setp_count: 45 22 145
# send_text #1P2196T40! 2196
# send_text #2P1083T40! 1083
# send_text #3P1500T40! 1500
# send_text #4P762T40! 762
# send_text #5P1980T40! 1980
# send_text #6P1500T40! 1500
# send_text #7P2238T40! 2238
# send_text #8P1020T40! 1020
# send_text #9P1500T40! 1500
# send_text #10P804T40! 804
# send_text #11P1917T40! 1917
# send_text #12P1500T40! 1500
# setp_count: 65 32 165
# send_text #1P2193T40! 2193
# send_text #2P1059T40! 1059
# send_text #3P1500T40! 1500
# send_text #4P753T40! 753
# send_text #5P1915T40! 1915
# send_text #6P1500T40! 1500
# send_text #7P2247T40! 2247
# send_text #8P1085T40! 1085
# send_text #9P1500T40! 1500
# send_text #10P807T40! 807
# send_text #11P1941T40! 1941
# send_text #12P1500T40! 1500
# setp_count: 85 42 185
# send_text #1P2188T40! 2188
# send_text #2P1036T40! 1036
# send_text #3P1500T40! 1500
# send_text #4P780T40! 780
# send_text #5P1853T40! 1853
# send_text #6P1500T40! 1500
# send_text #7P2220T40! 2220
# send_text #8P1147T40! 1147
# send_text #9P1500T40! 1500
# send_text #10P812T40! 812
# send_text #11P1964T40! 1964
# send_text #12P1500T40! 1500
# setp_count: 105 52 5
# send_text #1P2184T40! 2184
# send_text #2P1008T40! 1008
# send_text #3P1500T40! 1500
# send_text #4P801T40! 801
# send_text #5P1866T40! 1866
# send_text #6P1500T40! 1500
# send_text #7P2199T40! 2199
# send_text #8P1134T40! 1134
# send_text #9P1500T40! 1500
# send_text #10P816T40! 816
# send_text #11P1992T40! 1992
# send_text #12P1500T40! 1500
# setp_count: 125 62 25
# send_text #1P2210T40! 2210
# send_text #2P985T40! 985
# send_text #3P1500T40! 1500
# send_text #4P801T40! 801
# send_text #5P1892T40! 1892
# send_text #6P1500T40! 1500
# send_text #7P2199T40! 2199
# send_text #8P1108T40! 1108
# send_text #9P1500T40! 1500
# send_text #10P790T40! 790
# send_text #11P2015T40! 2015
# send_text #12P1500T40! 1500
# setp_count: 145 72 45
# send_text #1P2238T40! 2238
# send_text #2P1020T40! 1020
# send_text #3P1500T40! 1500
# send_text #4P804T40! 804
# send_text #5P1917T40! 1917
# send_text #6P1500T40! 1500
# send_text #7P2196T40! 2196
# send_text #8P1083T40! 1083
# send_text #9P1500T40! 1500
# send_text #10P762T40! 762
# send_text #11P1980T40! 1980
# send_text #12P1500T40! 1500
# setp_count: 165 82 65
# send_text #1P2247T40! 2247
# send_text #2P1085T40! 1085
# send_text #3P1500T40! 1500
# send_text #4P807T40! 807
# send_text #5P1941T40! 1941
# send_text #6P1500T40! 1500
# send_text #7P2193T40! 2193
# send_text #8P1059T40! 1059
# send_text #9P1500T40! 1500
# send_text #10P753T40! 753
# send_text #11P1915T40! 1915
# send_text #12P1500T40! 1500
# setp_count: 185 92 85
# send_text #1P2220T40! 2220
# send_text #2P1147T40! 1147
# send_text #3P1500T40! 1500
# send_text #4P812T40! 812
# send_text #5P1964T40! 1964
# send_text #6P1500T40! 1500
# send_text #7P2188T40! 2188
# send_text #8P1036T40! 1036
# send_text #9P1500T40! 1500
# send_text #10P780T40! 780
# send_text #11P1853T40! 1853
# send_text #12P1500T40! 1500
# setp_count: 6 103 106
# send_text #1P2199T40! 2199
# send_text #2P1132T40! 1132
# send_text #3P1500T40! 1500
# send_text #4P815T40! 815
# send_text #5P1994T40! 1994
# send_text #6P1500T40! 1500
# send_text #7P2185T40! 2185
# send_text #8P1006T40! 1006
# send_text #9P1500T40! 1500
# send_text #10P801T40! 801
# send_text #11P1868T40! 1868
# send_text #12P1500T40! 1500
# setp_count: 26 113 126
# send_text #1P2199T40! 2199
# send_text #2P1106T40! 1106
# send_text #3P1500T40! 1500
# send_text #4P788T40! 788
# send_text #5P2014T40! 2014
# send_text #6P1500T40! 1500
# send_text #7P2212T40! 2212
# send_text #8P986T40! 986
# send_text #9P1500T40! 1500
# send_text #10P801T40! 801
# send_text #11P1894T40! 1894
# send_text #12P1500T40! 1500
# setp_count: 46 123 146
# send_text #1P2196T40! 2196
# send_text #2P1081T40! 1081
# send_text #3P1500T40! 1500
# send_text #4P761T40! 761
# send_text #5P1977T40! 1977
# send_text #6P1500T40! 1500
# send_text #7P2239T40! 2239
# send_text #8P1023T40! 1023
# send_text #9P1500T40! 1500
# send_text #10P804T40! 804
# send_text #11P1919T40! 1919
# send_text #12P1500T40! 1500
# setp_count: 66 133 166
# send_text #1P2193T40! 2193
# send_text #2P1057T40! 1057
# send_text #3P1500T40! 1500
# send_text #4P753T40! 753
# send_text #5P1911T40! 1911
# send_text #6P1500T40! 1500
# send_text #7P2247T40! 2247
# send_text #8P1089T40! 1089
# send_text #9P1500T40! 1500
# send_text #10P807T40! 807
# send_text #11P1943T40! 1943
# send_text #12P1500T40! 1500
# setp_count: 86 143 186
# send_text #1P2188T40! 2188
# send_text #2P1034T40! 1034
# send_text #3P1500T40! 1500
# send_text #4P782T40! 782
# send_text #5P1851T40! 1851
# send_text #6P1500T40! 1500
# send_text #7P2218T40! 2218
# send_text #8P1149T40! 1149
# send_text #9P1500T40! 1500
# send_text #10P812T40! 812
# send_text #11P1966T40! 1966
# send_text #12P1500T40! 1500
# setp_count: 106 153 6
# send_text #1P2185T40! 2185
# send_text #2P1006T40! 1006
# send_text #3P1500T40! 1500
# send_text #4P801T40! 801
# send_text #5P1868T40! 1868
# send_text #6P1500T40! 1500
# send_text #7P2199T40! 2199
# send_text #8P1132T40! 1132
# send_text #9P1500T40! 1500
# send_text #10P815T40! 815
# send_text #11P1994T40! 1994
# send_text #12P1500T40! 1500
# setp_count: 126 163 26
# send_text #1P2212T40! 2212
# send_text #2P986T40! 986
# send_text #3P1500T40! 1500
# send_text #4P801T40! 801
# send_text #5P1894T40! 1894
# send_text #6P1500T40! 1500
# send_text #7P2199T40! 2199
# send_text #8P1106T40! 1106
# send_text #9P1500T40! 1500
# send_text #10P788T40! 788
# send_text #11P2014T40! 2014
# send_text #12P1500T40! 1500
# setp_count: 146 173 46
# send_text #1P2239T40! 2239
# send_text #2P1023T40! 1023
# send_text #3P1500T40! 1500
# send_text #4P804T40! 804
# send_text #5P1919T40! 1919
# send_text #6P1500T40! 1500
# send_text #7P2196T40! 2196
# send_text #8P1081T40! 1081
# send_text #9P1500T40! 1500
# send_text #10P761T40! 761
# send_text #11P1977T40! 1977
# send_text #12P1500T40! 1500
# setp_count: 166 183 66
# send_text #1P2247T40! 2247
# send_text #2P1089T40! 1089
# send_text #3P1500T40! 1500
# send_text #4P807T40! 807
# send_text #5P1943T40! 1943
# send_text #6P1500T40! 1500
# send_text #7P2193T40! 2193
# send_text #8P1057T40! 1057
# send_text #9P1500T40! 1500
# send_text #10P753T40! 753
# send_text #11P1911T40! 1911
# send_text #12P1500T40! 1500
# setp_count: 186 193 86
# send_text #1P2218T40! 2218
# send_text #2P1149T40! 1149
# send_text #3P1500T40! 1500
# send_text #4P812T40! 812
# send_text #5P1966T40! 1966
# send_text #6P1500T40! 1500
# send_text #7P2188T40! 2188
# send_text #8P1034T40! 1034
# send_text #9P1500T40! 1500
# send_text #10P782T40! 782
# send_text #11P1851T40! 1851
# send_text #12P1500T40! 1500
# setp_count: 6 3 106
# send_text #1P2199T40! 2199
# send_text #2P1132T40! 1132
# send_text #3P1500T40! 1500
# send_text #4P815T40! 815
# send_text #5P1994T40! 1994
# send_text #6P1500T40! 1500
# send_text #7P2185T40! 2185
# send_text #8P1006T40! 1006
# send_text #9P1500T40! 1500
# send_text #10P801T40! 801
# send_text #11P1868T40! 1868
# send_text #12P1500T40! 1500
# setp_count: 26 13 126
# send_text #1P2199T40! 2199
# send_text #2P1106T40! 1106
# send_text #3P1500T40! 1500
# send_text #4P788T40! 788
# send_text #5P2014T40! 2014
# send_text #6P1500T40! 1500
# send_text #7P2212T40! 2212
# send_text #8P986T40! 986
# send_text #9P1500T40! 1500
# send_text #10P801T40! 801
# send_text #11P1894T40! 1894
# send_text #12P1500T40! 1500
# setp_count: 46 23 146
# send_text #1P2196T40! 2196
# send_text #2P1081T40! 1081
# send_text #3P1500T40! 1500
# send_text #4P761T40! 761
# send_text #5P1977T40! 1977
# send_text #6P1500T40! 1500
# send_text #7P2239T40! 2239
# send_text #8P1023T40! 1023
# send_text #9P1500T40! 1500
# send_text #10P804T40! 804
# send_text #11P1919T40! 1919
# send_text #12P1500T40! 1500
# setp_count: 66 33 166
# send_text #1P2193T40! 2193
# send_text #2P1057T40! 1057
# send_text #3P1500T40! 1500
# send_text #4P753T40! 753
# send_text #5P1911T40! 1911
# send_text #6P1500T40! 1500
# send_text #7P2247T40! 2247
# send_text #8P1089T40! 1089
# send_text #9P1500T40! 1500
# send_text #10P807T40! 807
# send_text #11P1943T40! 1943
# send_text #12P1500T40! 1500
# setp_count: 86 43 186
# send_text #1P2188T40! 2188
# send_text #2P1034T40! 1034
# send_text #3P1500T40! 1500
# send_text #4P782T40! 782
# send_text #5P1851T40! 1851
# send_text #6P1500T40! 1500
# send_text #7P2218T40! 2218
# send_text #8P1149T40! 1149
# send_text #9P1500T40! 1500
# send_text #10P812T40! 812
# send_text #11P1966T40! 1966
# send_text #12P1500T40! 1500
# setp_count: 106 53 6
# send_text #1P2185T40! 2185
# send_text #2P1006T40! 1006
# send_text #3P1500T40! 1500
# send_text #4P801T40! 801
# send_text #5P1868T40! 1868
# send_text #6P1500T40! 1500
# send_text #7P2199T40! 2199
# send_text #8P1132T40! 1132
# send_text #9P1500T40! 1500
# send_text #10P815T40! 815
# send_text #11P1994T40! 1994
# send_text #12P1500T40! 1500
# setp_count: 126 63 26
# send_text #1P2212T40! 2212
# send_text #2P986T40! 986
# send_text #3P1500T40! 1500
# send_text #4P801T40! 801
# send_text #5P1894T40! 1894
# send_text #6P1500T40! 1500
# send_text #7P2199T40! 2199
# send_text #8P1106T40! 1106
# send_text #9P1500T40! 1500
# send_text #10P788T40! 788
# send_text #11P2014T40! 2014
# send_text #12P1500T40! 1500
# setp_count: 146 73 46
# send_text #1P2239T40! 2239
# send_text #2P1023T40! 1023
# send_text #3P1500T40! 1500
# send_text #4P804T40! 804
# send_text #5P1919T40! 1919
# send_text #6P1500T40! 1500
# send_text #7P2196T40! 2196
# send_text #8P1081T40! 1081
# send_text #9P1500T40! 1500
# send_text #10P761T40! 761
# send_text #11P1977T40! 1977
# send_text #12P1500T40! 1500
# setp_count: 166 83 66
# send_text #1P2247T40! 2247
# send_text #2P1089T40! 1089
# send_text #3P1500T40! 1500
# send_text #4P807T40! 807
# send_text #5P1943T40! 1943
# send_text #6P1500T40! 1500
# send_text #7P2193T40! 2193
# send_text #8P1057T40! 1057
# send_text #9P1500T40! 1500
# send_text #10P753T40! 753
# send_text #11P1911T40! 1911
# send_text #12P1500T40! 1500
# setp_count: 186 93 86
# send_text #1P2218T40! 2218
# send_text #2P1149T40! 1149
# send_text #3P1500T40! 1500
# send_text #4P812T40! 812
# send_text #5P1966T40! 1966
# send_text #6P1500T40! 1500
# send_text #7P2188T40! 2188
# send_text #8P1034T40! 1034
# send_text #9P1500T40! 1500
# send_text #10P782T40! 782
# send_text #11P1851T40! 1851
# ...
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 137 68 37
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 157 78 57
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 177 88 77
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 197 98 97
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 18 109 118
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 38 119 138
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 58 129 158
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 78 139 178
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 98 149 198
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 118 159 18
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 138 169 38
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 158 179 58
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 178 189 78
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 198 199 98
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 18 9 118
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 38 19 138
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 58 29 158
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 78 39 178
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 98 49 198
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 118 59 18
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 138 69 38
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 158 79 58
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 178 89 78
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 198 99 98
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 19 109 119
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 39 119 139
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 59 129 159
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 79 139 179
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 99 149 199
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 119 159 19
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 139 169 39
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 159 179 59
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 179 189 79
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 199 199 99
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 19 9 119
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 39 19 139
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 59 29 159
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 79 39 179
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 99 49 199
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 119 59 19
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 139 69 39
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 159 79 59
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 179 89 79
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 0 100 100
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 20 110 120
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# setp_count: 40 120 140
# send_text #1P2249T40! 2249
# send_text #2P1043T40! 1043
# send_text #3P1500T40! 1500
# send_text #4P751T40! 751
# send_text #5P1957T40! 1957
# send_text #6P1500T40! 1500
# send_text #7P2249T40! 2249
# send_text #8P1043T40! 1043
# send_text #9P1500T40! 1500
# send_text #10P751T40! 751
# send_text #11P1957T40! 1957
# send_text #12P1500T40! 1500
# walk frount

# %% [raw]
# ###### The above cell probably only shows 1 class. Keep in mind that the model
# is able to identify multiple projects in the given picture.
# You can try a different picture by specifying a new `image_path`.
#
# Remember to clean up when you are done.

# %%
capture.release()
n2cube.dpuDestroyTask(task)
n2cube.dpuDestroyKernel(kernel)
# Out:
# 0

# %% [markdown]
# Copyright (C) 2020 Xilinx, Inc.
